# %%
a = [1,2,3,4]
a
# Out:
# [1, 2, 3, 4]

# %%
a[0] = 100
a
# Out:
# [100, 2, 3, 4]

# %%
a.insert(3,200)
a
# Out:
# [100, 2, 3, 200, 4]

# %%
a.sort()
a
# Out:
# [2, 3, 4, 100, 200]

# %%
s = "hello world"
s
# Out:
# 'hello world'

# %%
s[0] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-5994e1a74598> in <module>()
# ----> 1 s[0] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %%
s = 'hello world'
print s.replace('he','mars')
print s
# Out:
# marsllo world
# hello world

# %%
s = bytearray('abcde')
s[1:3] = '12'
s
# Out:
# bytearray(b'a12de')

# %%
t = (10,11,12,13,14)
t
# Out:
# (10, 11, 12, 13, 14)

# %%
t[0]
# Out:
# 10

# %%
t[1:3]
# Out:
# (11, 12)

# %%
t[0] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-c8aeb8cd20ae> in <module>()
# ----> 1 t[0] = 1
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = (10,)
print a
print type(a)
# Out:
# (10,)
# <type 'tuple'>

# %%
a = (10)
print type(a)
# Out:
# <type 'int'>

# %%
a = [10,11,12,13,14]
tuple(a)
# Out:
# (10, 11, 12, 13, 14)

# %%
from numpy.random import rand
values = rand(10000,4)
lst = [list(row) for row in values]
tup = tuple(tuple(row) for row in values)
print lst
print tup
# Out:
# [[0.6338809928703477, 0.6554829189928827, 0.008342829954146147, 0.28479342986581946], [0.1281325073375772, 0.7260687343244941, 0.14651702909544695, 0.6769075055104598], [0.7463135207709125, 0.9817429157262982, 0.7242388726849703, 0.5038883236484591], [0.9567527052196744, 0.1321550674723615, 0.4753502622659539, 0.8045724196722391], [0.5018494384444442, 0.5227429300042703, 0.3457555628252508, 0.5221599156521108], [0.8528261440741522, 0.1695755992049408, 0.1887502545087243, 0.8151868976142856], [0.7870461714873659, 0.2226211547344994, 0.6937942077197004, 0.5632333782698938], [0.5662407783196008, 0.5874781504784159, 0.876505859341235, 0.12132439589242316], [0.778515273349276, 0.5063231763201368, 0.3736239910276322, 0.58180243235851], [0.02396777552753715, 0.37306953197554005, 0.16288599249695646, 0.8843477455600612], [0.6465403076644262, 0.07555857389420972, 0.7724130363554726, 0.010114263539722224], [0.330543751076535, 0.7015182876646723, 0.09615897383272198, 0.4712588282789769], [0.11819360171946502, 0.045366932539817384, 0.6494829946077494, 0.7188893738482269], [0.21100165276690996, 0.12454387511401821, 0.023383803392024616, 0.7882051307795711], [0.3245459937807439, 0.9508203828380284, 0.22306065796745433, 0.1840704815640879], [0.7900478245232845, 0.8215934848138559, 0.3561720781121228, 0.9175700192002378], [0.7379519226177546, 0.31125230808094706, 0.14029413762721765, 0.5197643894763387], [0.4935599467637334, 0.7396922605031385, 0.4383502543209642, 0.16466721664292716], [0.2754946690576515, 0.447071187597464, 0.03141591354178774, 0.5014441891284578], [0.8376041813386542, 0.03053418173429967, 0.6889337574686564, 0.34746743671029034], [0.6156345711109663, 0.6463778531598743, 0.5384268029245091, 0.02579232614997118], [0.33217849681797673, 0.40949830156530465, 0.4632907879984861, 0.41954086292454884], [0.015710289758797513, 0.5986499211771913, 0.5423470693601428, 0.5724947931688442], [0.005963137935790619, 0.9104497581437613, 0.22624635874948273, 0.539804253110179], [0.44846397919419434, 0.3014380447430437, 0.43622116285350143, 0.8895929517723903], [0.43528725932280066,
, 0.03053418173429967, 0.6889337574686564, 0.34746743671029034), (0.6156345711109663, 0.6463778531598743, 0.5384268029245091, 0.02579232614997118), (0.33217849681797673, 0.40949830156530465, 0.4632907879984861, 0.41954086292454884), (0.015710289758797513, 0.5986499211771913, 0.5423470693601428, 0.5724947931688442), (0.005963137935790619, 0.9104497581437613, 0.22624635874948273, 0.539804253110179), (0.44846397919419434, 0.3014380447430437, 0.43622116285350143, 0.8895929517723903), (0.43528725932280066, 0.8910177452109977, 0.47008655688265744, 0.9643770359602012), (0.8749769576963361, 0.9305062955288363, 0.6088128162502688, 0.46793979744642955), (0.689833899432851, 0.7811743951718894, 0.4524013781937325, 0.15794257522803845), (0.5420484579822926, 0.3670019277109755, 0.6719670577422551, 0.13522149652282645), (0.017701920469699983, 0.5869139178244266, 0.027888566242210033, 0.4379509722821163), (0.08559393684081595, 0.36854984140829283, 0.07824668772357257, 0.14446639814327333), (0.7804548896434433, 0.4489598229730921, 0.19053960662415115, 0.2505360924018025), (0.5350221746674795, 0.8734550866009829, 0.33219357346682143, 0.6141524602896806), (0.5630645823629377, 0.441806463008134, 0.9431888292831654, 0.20886574684743442), (0.9938856690043366, 0.8205625750026325, 0.07473871554658862, 0.44409198973035446), (0.4038346806073265, 0.015690916725222936, 0.27845665919188867, 0.8398296808132002), (0.11640503429177351, 0.8869856326727092, 0.35019750283824846, 0.8601170154882586), (0.31771840928165773, 0.3813713701365625, 0.6826094377624298, 0.39629493253062165), (0.8213591632940981, 0.35114894934413887, 0.8492022722000893, 0.9316686342060605), (0.2048854603312149, 0.9751196660456357, 0.94756831422933, 0.009618633385653497), (0.04800178678763345, 0.416757823807561, 0.28522283258247105, 0.836942487689086), (0.9942712841472755, 0.3037259983034767, 0.08279683548407002, 0.4949935194527104), (0.8639218395933083, 0.8924297230131311, 0.5675534787651857, 0.1637677054849117), (0.1941689273377064, 0.4142847886059132, 0.7740461864234907, 0.5022913400277884), (0.5004692593866027, 0.285383713535754, 0.2003979935881337, 0.4732042237229219), (0.14975258252224988, 0.791978229881245, 0.9324013834808942, 0.9471895022966124), (0.003737310236080371, 0.7415712502531466, 0.2596887384220897, 0.3412014435038465), (0.5279765350566472, 0.7623839633997225, 0.7104741975111479, 0.12540484886139458), (0.068 ...

# %%
# %timeit for row in lst:list(row)
# Out:
# 100 loops, best of 3: 3.28 ms per loop

# %%
# %timeit for row in tup: tuple(row)
# Out:
# 100 loops, best of 3: 2.19 ms per loop

# %%
# %timeit for row in lst: a = row[0]+1
# Out:
# 100 loops, best of 3: 3.88 ms per loop

# %%
# %timeit for row in tup: a = row[0] + 1
# Out:
# 100 loops, best of 3: 3.73 ms per loop

# %%
a = {}
type(a)
# Out:
# dict

# %%
a = dict()
type(a)
# Out:
# dict

# %%
a["one"] = "this is number 1"
a["two"] = "this is number 2"
a
# Out:
# {'one': 'this is number 1', 'two': 'this is number 2'}

# %%
a["one"]
# Out:
# 'this is number 1'

# %%
a["one"] = "this is number 1, too"
a
# Out:
# {'one': 'this is number 1, too', 'two': 'this is number 2'}

# %%
b = {'one':'this is number 1','two':'this is number 2'}
b['one']
# Out:
# 'this is number 1'

# %%
print a
# Out:
# {'two': 'this is number 2', 'one': 'this is number 1, too'}

# %%
print b
# Out:
# {'two': 'this is number 2', 'one': 'this is number 1'}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-6a1284577a36> in <module>()
# ----> 1 a[0]
#
# KeyError: 0

# %%
synonyms = {}
synonyms['mutable'] = ['changeable','variable','varying','fluctuating',
                      'shifting','inconsistent','unpredictable','inconstant',
                      'fickle','uneven','unstable','protean']
synonyms['immutable'] = ['fixed','set','rigid','inflexible',
                         'permanent','established','carved in stone']
synonyms
# Out:
# {'immutable': ['fixed',
#   'set',
#   'rigid',
#   'inflexible',
#   'permanent',
#   'established',
#   'carved in stone'],
#  'mutable': ['changeable',
#   'variable',
#   'varying',
#   'fluctuating',
#   'shifting',
#   'inconsistent',
#   'unpredictable',
#   'inconstant',
#   'fickle',
#   'uneven',
#   'unstable',
#   'protean']}

# %%
e1 = {'mag':0.05,'width':20}
e2 = {'mag':0.04,'width':25}
e3 = {'mag':0.05,'width':80}
e4 = {'mag':0.03,'width':30}
events = {500:e2,760:e2,3001:e3,4180:e4}
events
# Out:
# {500: {'mag': 0.04, 'width': 25},
#  760: {'mag': 0.04, 'width': 25},
#  3001: {'mag': 0.05, 'width': 80},
#  4180: {'mag': 0.03, 'width': 30}}

# %%
people = [
    {'first': 'Sam', 'last': 'Malone', 'name': 35},
    {'first': 'Woody', 'last': 'Boyd', 'name': 21},
    {'first': 'Norm', 'last': 'Peterson', 'name': 34},
    {'first': 'Diane', 'last': 'Chambers', 'name': 33}
]
people
# Out:
# [{'first': 'Sam', 'last': 'Malone', 'name': 35},
#  {'first': 'Woody', 'last': 'Boyd', 'name': 21},
#  {'first': 'Norm', 'last': 'Peterson', 'name': 34},
#  {'first': 'Diane', 'last': 'Chambers', 'name': 33}]

# %%
inventory = dict(
[('foozelator',123),
 ('frombicator',18),
 ('spatzleblock',34),
 ('snitzelhogen',23)
])
inventory
# Out:
# {'foozelator': 123, 'frombicator': 18, 'snitzelhogen': 23, 'spatzleblock': 34}

# %%
inventory['frombicator']+=1
inventory
# Out:
# {'foozelator': 123, 'frombicator': 19, 'snitzelhogen': 23, 'spatzleblock': 34}

# %%
connections = {}
connections[('new york','austin')]=100
connections[('austin','new york')] = 200

# %%
print connections[('austin','new york')]
print connections[('new york','austin')]
# Out:
# 200
# 100

# %%
a = {}
a["one"] = "this is number 1"
a["two"] = "this is number 2"

# %%
a["three"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-ba528808dd1a> in <module>()
# ----> 1 a["three"]
#
# KeyError: 'three'

# %%
print a.get('three')
# Out:
# None

# %%
a.get('three','undefined')
# Out:
# 'undefined'

# %%
a
# Out:
# {'one': 'this is number 1', 'two': 'this is number 2'}

# %%
a.pop("two")
# Out:
# 'this is number 2'

# %%
a
# Out:
# {'one': 'this is number 1'}

# %%
a.pop("two",'not exist')
# Out:
# 'not exist'

# %%
del a["one"]
a
# Out:
# {}

# %%
person = {}
person['first'] = "jmes"
person['last'] = "Maxwell"
person['born'] = 1831
print person
# Out:
# {'born': 1831, 'last': 'Maxwell', 'first': 'jmes'}

# %%
person_modifications = {'first':'James','middle':'Clerk'}
person.update(person_modifications)
print person
# Out:
# {'middle': 'Clerk', 'born': 1831, 'last': 'Maxwell', 'first': 'James'}

# %%
barn = {'cows':1,'dogs':5, 'cats':3}

# %%
'chickens' in barn
# Out:
# False

# %%
'cows' in barn
# Out:
# True

# %%
barn.keys()
# Out:
# ['cows', 'cats', 'dogs']

# %%
barn.values()
# Out:
# [1, 3, 5]
